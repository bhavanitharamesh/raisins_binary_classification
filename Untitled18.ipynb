# %%
iimport pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\user\Desktop\ML\July_1\Raisin_Dataset.csv")
data.sample(5)
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 841   92472       424.419993       282.211505      0.746902       95982
# 870  179668       690.433416       332.553258      0.876359      181954
# 653   97377       503.992068       252.499625      0.865448      101317
# 94    52243       331.451147       206.759599      0.781583       55774
# 327   66998       338.586640       257.343820      0.649861       69844
#
#        Extent  Perimeter    Class
# 841  0.746163   1204.610    Besni
# 870  0.779403   1681.985    Besni
# 653  0.708423   1281.252    Besni
# 94   0.714434    934.547  Kecimen
# 327  0.757605   1006.220  Kecimen

# %%
data.shape
# Out:
# (900, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             900 non-null    int64
#  1   MajorAxisLength  900 non-null    float64
#  2   MinorAxisLength  900 non-null    float64
#  3   Eccentricity     900 non-null    float64
#  4   ConvexArea       900 non-null    int64
#  5   Extent           900 non-null    float64
#  6   Perimeter        900 non-null    float64
#  7   Class            900 non-null    object
# dtypes: float64(5), int64(2), object(1)
# memory usage: 56.4+ KB

# %%
data.describe()
# Out:
#                 Area  MajorAxisLength  MinorAxisLength  Eccentricity  \
# count     900.000000       900.000000       900.000000    900.000000
# mean    87804.127778       430.929950       254.488133      0.781542
# std     39002.111390       116.035121        49.988902      0.090318
# min     25387.000000       225.629541       143.710872      0.348730
# 25%     59348.000000       345.442898       219.111126      0.741766
# 50%     78902.000000       407.803951       247.848409      0.798846
# 75%    105028.250000       494.187014       279.888575      0.842571
# max    235047.000000       997.291941       492.275279      0.962124
#
#           ConvexArea      Extent    Perimeter
# count     900.000000  900.000000   900.000000
# mean    91186.090000    0.699508  1165.906636
# std     40769.290132    0.053468   273.764315
# min     26139.000000    0.379856   619.074000
# 25%     61513.250000    0.670869   966.410750
# 50%     81651.000000    0.707367  1119.509000
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
def count_outliers_iqr(df, thresh=1.5):
    result = []
    for col in df.select_dtypes(include=['number']).columns:
        
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - thresh * IQR
        upper_bound = Q3 + thresh * IQR

        count = (
            (df[col] < lower_bound) |
            (df[col] > upper_bound)
        ).sum()

        result.append([col, count])

    return pd.DataFrame(
        result,
        columns=["Column", "Outlier_Count"]
    )

# %%
outlier_report = count_outliers_iqr(data)
outlier_report
# Out:
#             Column  Outlier_Count
# 0             Area             41
# 1  MajorAxisLength             17
# 2  MinorAxisLength             26
# 3     Eccentricity             43
# 4       ConvexArea             42
# 5           Extent             21
# 6        Perimeter             17

# %%
data.Class.value_counts()
# Out:
# Class
# Kecimen    450
# Besni      450
# Name: count, dtype: int64

# %%
X = data.drop(columns=['Class'])
y = data.Class

# %%
data["Class"].replace({"Kecimen":1,"Besni":0})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12432\1552796432.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data["Class"].replace({"Kecimen":1,"Besni":0})
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 895    0
# 896    0
# 897    0
# 898    0
# 899    0
# Name: Class, Length: 900, dtype: int64

# %%
data["Class"]
# Out:
# 0      Kecimen
# 1      Kecimen
# 2      Kecimen
# 3      Kecimen
# 4      Kecimen
#         ...
# 895      Besni
# 896      Besni
# 897      Besni
# 898      Besni
# 899      Besni
# Name: Class, Length: 900, dtype: object

# %%
y.sample(1)
# Out:
# 462    Besni
# Name: Class, dtype: object

# %%
from sklearn.model_selection  import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=45)

# %%
X_train.shape , X_test.shape
# Out:
# ((810, 7), (90, 7))

# %%
data.dtypes
# Out:
# Area                 int64
# MajorAxisLength    float64
# MinorAxisLength    float64
# Eccentricity       float64
# ConvexArea           int64
# Extent             float64
# Perimeter          float64
# Class               object
# dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier(
    n_estimators=10,
    criterion="gini",
    max_depth=100,
    random_state=42
)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=100, n_estimators=10, random_state=42)

# %%
y_pred=model.predict(X_test)

# %%
model.score(X_train,y_train)
# Out:
# 0.9888888888888889

# %%
model.score(X_test,y_test)
# Out:
# 0.8777777777777778

# %%
from sklearn.metrics import(confusion_matrix, classification_report)
import seaborn as sns
cm=confusion_matrix(y_test,y_pred)
sns.heatmap(cm, annot=True, cmap="Blues")
# Out:
# <Axes: >

# %%
classificationreport=classification_report(y_test,y_pred)
print(classificationreport)
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.90      0.88      0.89        51
#      Kecimen       0.85      0.87      0.86        39
#
#     accuracy                           0.88        90
#    macro avg       0.88      0.88      0.88        90
# weighted avg       0.88      0.88      0.88        90

# %%
import pickle
with open("Randomforest_sample.pkl","wb") as file:
    pickle.dump(model,file)
with open("Randomforest_sample.pkl","rb") as file:
    loaded_sample=pickle.load(file)

print("Loaded")
# Out:
# Loaded

# %%
test_data=dict(zip(X_train.columns,round(X_test.iloc[3],0)))
print(test_data)
test_df = pd.DataFrame([test_data])
# Out:
# {'Area': 59654.0, 'MajorAxisLength': 351.0, 'MinorAxisLength': 219.0, 'Eccentricity': 1.0, 'ConvexArea': 62384.0, 'Extent': 1.0, 'Perimeter': 980.0}

# %%
model.predict(test_df)
# Out:
# array(['Kecimen'], dtype=object)
